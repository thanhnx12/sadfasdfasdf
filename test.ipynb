# %%
import google.generativeai as genai

genai.configure(api_key= 'AIzaSyDBECQnpdlHjyw0m90b8nMRBsA_oaE0WXU')
model = genai.GenerativeModel('gemini-1.5-pro-latest')

# %%
input_string = """
You are a data scientist working on a relation extraction task. Please do the following task and do not give output in the markdown format.One sample in relation extraction datasets consists of a relation, a context, a pair of head and tail entities in the context.The head entity has the relation with the tail entity.
Relation "person countries of residence" means a person is living in a country.
Here is an example:
Relation: person countries of residence
Context: iran 's top nuclear negotiator , ali larijani , was asked by state tv whether the country had started converting into gas a second batch of uranium , as it had planned to do at its isfahan nuclear facility .
Head Entity: ali larijani
Tail Entity: iran
Please generate 5 diversity samples (must have full : Relation , Context , Head Entity , Tail Entity) like the above example for the relation "person countries of residence":"""

# %%
generation_config = {
  "temperature": 0.0,
  "response_mime_type": "text/plain",
}

# %%
response = model.generate_content(input_string,generation_config=generation_config)

# %%
response.text
# Out:
# 'Relation: person countries of residence\nContext: After fleeing the war in syria , the family settled in jordan , where they have been living for the past five years .\nHead Entity: the family\nTail Entity: jordan\n\nRelation: person countries of residence\nContext: Elon musk , the ceo of tesla and spacex , recently relocated to texas from california .\nHead Entity: Elon musk\nTail Entity: texas\n\nRelation: person countries of residence\nContext: Although she was born in argentina , she has lived in spain for most of her life and now considers madrid her home .\nHead Entity: she\nTail Entity: spain\n\nRelation: person countries of residence\nContext: My grandparents immigrated to canada from ireland in the 1950s and built a new life for themselves in toronto .\nHead Entity: My grandparents\nTail Entity: canada\n\nRelation: person countries of residence\nContext: The author , who currently resides in japan , draws inspiration for his novels from the rich cultural heritage of the country .\nHead Entity: The author\nTail Entity: japan \n'

# %%
import json

res = json.loads(response.text) 
res
# Out:
# [{'Relation': 'person countries of residence',
#   'Context': 'russian president vladimir putin signed a decree on wednesday to expedite russian passports to residents of two regions of eastern ukraine , a move that could presage a russian military advance .',
#   'Head Entity': 'vladimir putin',
#   'Tail Entity': 'russia'},
#  {'Relation': 'person countries of residence',
#   'Context': 'in february 2021 , meghan markle accused the british royal family of racism .',
#   'Head Entity': 'meghan markle',
#   'Tail Entity': 'britain'},
#  {'Relation': 'person countries of residence',
#   'Context': 'during a visit to kyiv on saturday , british prime minister boris johnson announced a new package of military aid for ukraine .',
#   'Head Entity': 'boris johnson',
#   'Tail Entity': 'britain'},
#  {'Relation': 'person countries of residence',
#   'Context': 'the agreement was signed by chinese foreign minister wang yi and his solomon islands counterpart , jeremiah manele .',
#   'Head Entity': 'jeremiah manele',
#   'Tail Entity': 'solomon islands'},
#  {'Relation': 'person countries of residence',
#   'Context': "the united states has imposed sanctions on alexander lukashenko , the president of belarus , over his government 's crackdown on protesters .",
#   'Head Entity': 'alexander lukashenko',
#   'Tail Entity': 'belarus'}]

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.17.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/thanh/miniconda3/lib/python3.12/site-packages (from wandb) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /home/thanh/miniconda3/lib/python3.12/site-packages (from wandb) (3.10.0)
# Collecting protobuf!=4.21.0,<6,>=3.19.0 (from wandb)
#   Downloading protobuf-5.27.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: psutil>=5.0.0 in /home/thanh/miniconda3/lib/python3.12/site-packages (from wandb) (5.9.8)
# Collecting pyyaml (from wandb)
#   Downloading PyYAML-6.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/thanh/miniconda3/lib/python3.12/site-packages (from wandb) (2.31.0)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-2.5.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /home/thanh/miniconda3/lib/python3.12/site-packages (from wandb) (68.2.2)
# Requirement already satisfied: six>=1.4.0 in /home/thanh/miniconda3/lib/python3.12/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/thanh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/thanh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/thanh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/thanh/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb) (2024.6.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading wandb-0.17.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 8.6 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 7.4 MB/s eta 0:00:00
# Downloading protobuf-5.27.1-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 kB 16.5 MB/s eta 0:00:00
# Downloading sentry_sdk-2.5.1-py2.py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.6/289.6 kB 11.6 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (724 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 11.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading setproctitle-1.3.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 15.2 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, pyyaml, protobuf, docker-pycreds, gitdb, gitpython, wandb
# Successfully installed docker-pycreds-0.4.0 gitdb-4.0.11 gitpython-3.1.43 protobuf-5.27.1 pyyaml-6.0.1 sentry-sdk-2.5.1 setproctitle-1.3.3 smmap-5.0.1 wandb-0.17.1

# %%
import wandb
api = wandb.Api()
run = api.run("/banana1209/CPL/runs/kungqnnh")
print(run.history())
# Out:
# Unable to load pandas, call history with pandas=False
# [{'_step': 0, 'loss': 12.887609481811523, 'infoNCE_loss': 11.717316627502441, '_runtime': 37.49209690093994, '_timestamp': 1718246842.586675}, {'_step': 1, 'loss': 13.127002716064453, 'infoNCE_loss': 2.637500286102295, '_runtime': 38.252506256103516, '_timestamp': 1718246843.3470843}, {'_step': 2, 'loss': 12.982297897338867, 'infoNCE_loss': 2.650418758392334, '_runtime': 38.84844923019409, '_timestamp': 1718246843.9430273}, {'_step': 3, 'loss': 12.695256233215332, 'infoNCE_loss': 2.644566774368286, '_runtime': 39.44326210021973, '_timestamp': 1718246844.5378401}, {'_step': 4, 'loss': 12.9495849609375, 'infoNCE_loss': 2.696476697921753, '_runtime': 40.03940439224243, '_timestamp': 1718246845.1339824}, {'_step': 5, 'loss': 12.285609245300293, 'infoNCE_loss': 2.624011516571045, '_runtime': 40.63514184951782, '_timestamp': 1718246845.7297199}, {'_step': 6, 'loss': 12.600069046020508, 'infoNCE_loss': 2.6415162086486816, '_runtime': 41.23189616203308, '_timestamp': 1718246846.3264742}, {'_step': 7, 'loss': 12.546974182128906, 'infoNCE_loss': 2.6884095668792725, '_runtime': 41.8321168422699, '_timestamp': 1718246846.9266949}, {'_step': 8, 'loss': 12.548075675964355, 'infoNCE_loss': 2.6415164470672607, '_runtime': 42.429699182510376, '_timestamp': 1718246847.5242772}, {'_step': 9, 'loss': 12.056106567382812, 'infoNCE_

# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     130 try:
# --> 131     result = self._call_fn(*args, **kwargs)
#     132     # Only print resolved attempts once every minute
#
# File ~/miniconda3/lib/python3.12/site-packages/wandb/apis/public/files.py:172, in File.download(self, root, replace, exist_ok, api)
#     168         raise ValueError(
#     169             "File already exists, pass replace=True to overwrite or exist_ok=True to leave it as is and don't error."
#     170         )
# --> 172 util.download_file_from_url(path, self.url, api.api_key)
#     173 return open(path)
#
# File ~/miniconda3/lib/python3.12/site-packages/wandb/util.py:1318, in download_file_from_url(dest_path, source_url, api_key)
#    1310 response = requests.get(
#    1311     source_url,
#    1312     auth=auth,
#    (...)
#    1316     timeout=5,
#    1317 )
# -> 1318 response.raise_for_status()
#    1320 if os.sep in dest_path:
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.wandb.ai/files/banana1209/CPL/kungqnnh/output.log
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 f.download()
#
# File ~/miniconda3/lib/python3.12/site-packages/wandb/apis/normalize.py:73, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      69         raise CommError(message, err.last_exception).with_traceback(
#      70             sys.exc_info()[2]
#      71         )
#      72 except Error as err:
# ---> 73     raise err
#      74 except Exception as err:
#      75     # gql raises server errors with dict's as strings...
#      76     if len(err.args) > 0:
#
# File ~/miniconda3/lib/python3.12/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File ~/miniconda3/lib/python3.12/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/wandb/sdk/lib/retry.py:147, in Retry.__call__(self, *args, **kwargs)
#     144     return result
#     145 except self._retryable_exceptions as e:
#     146     # if the secondary check fails, re-raise
# --> 147     retry_timedelta_triggered = check_retry_fn(e)
#     148     if not retry_timedelta_triggered:
#     149         raise
#
# File ~/miniconda3/lib/python3.12/site-packages/wandb/util.py:907, in no_retry_auth(e)
#     905     raise CommError(f"Permission denied to access {wandb.run.path}")
#     906 else:
# --> 907     raise CommError(
#     908         "It appears that you do not have permission to access the requested resource. "
#     909         "Please reach out to the project owner to grant you access. "
#     910         "If you have the correct permissions, verify that there are no issues with your networking setup."
#     911         f"(Error {e.response.status_code}: {e.response.reason})"
#     912     )
#
# CommError: It appears that you do not have permission to access the requested resource. Please reach out to the project owner to grant you access. If you have the correct permissions, verify that there are no issues with your networking setup.(Error 404: Not Found)
